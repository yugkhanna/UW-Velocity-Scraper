# %%
#importing necessary libraries
import requests
from bs4 import BeautifulSoup
import pandas
import csv

# %%
page = requests.get("http://velocity.uwaterloo.ca/companies/") #fetching page

# %%
page #checking response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify()) #printing page
# Out:
# <!DOCTYPE doctype html>
# <html class="no-js" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/images/logos/favicon.ico" rel="shortcut icon"/>
#   <title>
#    Companies – Velocity
#   </title>
#   <!-- Social Warfare v2.3.3 https://warfareplugins.com -->
#   <style>
#    @font-face {font-family: "sw-icon-font";src:url("http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/fonts/sw-icon-font.eot?ver=2.3.3");src:url("http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/fonts/sw-icon-font.eot?ver=2.3.3#iefix") format("embedded-opentype"),url("http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/fonts/sw-icon-font.woff?ver=2.3.3") format("woff"), url("http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/fonts/sw-icon-font.ttf?ver=2.3.3") format("truetype"),url("http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/fonts/sw-icon-font.svg?ver=2.3.3#1445203416") format("svg");font-weight: normal;font-style: normal;}
#   </style>
#   <!-- Social Warfare v2.3.3 https://warfareplugins.com -->
#   <link href="//www.formstack.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="http://velocity.uwaterloo.ca/events/?ical=1" rel="alternate" title="Velocity » iCal Feed" type="text/calendar"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/2\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/velocity.uwaterloo.ca\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.6.11"}};
# 			!function(a,b,c){function d(a){var c,d,e,f,g,h=b.createElement("canvas"),i=h.getContext&&h.getContext("2d"),j=String.fromCharCode;if(!i||!i.fillText)return!1;switch(i.textBaseline="top",i.font="600 32px Arial",a){case"flag":return i.fillText(j(55356,56806,55356,56826),0,0),!(h.toDataURL().length<3e3)&&(i.clearRect(0,0,h.width,h.height),i.fillText(j(55356,57331,65039,8205,55356,57096),0,0),c=h.toDataURL(),i.clearRect(0,0,h.width,h.height),i.fillText(j(55356,57331,55356,57096),0,0),d=h.toDataURL(),c!==d);case"diversity":return i.fillText(j(55356,57221),0,0),e=i.getImageData(16,16,1,1).data,f=e[0]+","+e[1]+","+e[2]+","+e[3],i.fillText(j(55356,57221,55356,57343),0,0),e=i.getImageData(16,16,1,1).data,g=e[0]+","+e[1]+","+e[2]+","+e[3],f!==g;case"simple":return i.fillText(j(55357,56835),0,0),0!==i.getImageData(16,16,1,1).data[0];case"unicode8":return i.fillText(j(55356,57135),0,0),0!==i.getImageData(16,16,1,1).data[0];case"unicode9":return i.fillText(j(55358,56631),0,0),0!==i.getImageData(16,16,1,1).data[0]}return!1}function e(a){var c=b.createElement("script");c.src=a,c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g,h,i;for(i=Array("simple","flag","unicode8","diversity","unicode9"),c.supports={everything:!0,everythingExceptFlag:!0},h=0;h<i.length;h++)c.supports[i[h]]=d(i[h]),c.supports.everything=c.supports.everything&&c.supports[i[h]],"flag"!==i[h]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[i[h]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="http://velocity.uwaterloo.ca/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=4.5" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/plugins/font-awesome-4-menus/css/font-awesome.min.css?ver=4.6.3" id="font-awesome-four-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.formstack.com/forms/css/2/wordpress-post.css?ver=4.6.11" id="formstack-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/plugins/wp-lightbox-2/styles/lightbox.min.css?ver=1.3.4" id="wp-lightbox-2.min.css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/css/style.min.css?ver=2.3.3" id="social_warfare-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/style.css?ver=1.0" id="pb-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://velocity.uwaterloo.ca/wp-content/plugins/mailchimp-for-wp/assets/css/form-basic.min.css?ver=4.0.3" id="mc4wp-form-basic-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="http://velocity.uwaterloo.ca/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript">
#   </script>
#   <script>
#    jQueryWP = jQuery;
#   </script>
#   <script src="http://velocity.uwaterloo.ca/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <script src="http://velocity.uwaterloo.ca/wp-content/plugins/mailchimp-widget/js/mailchimp-widget-min.js?ver=4.6.11" type="text/javascript">
#   </script>
#   <link href="http://velocity.uwaterloo.ca/wp-json/" rel="https://api.w.org/"/>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-48074128-1']);
# _gaq.push(['_trackPageview']);
# (function() {
# var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# })();
#   </script>
#   <!-- <meta name="NextGEN" version="2.1.49" /> -->
#   <meta content="v1" name="tec-api-version"/>
#   <meta content="http://velocity.uwaterloo.ca" name="tec-api-origin"/>
#   <link href="http://velocity.uwaterloo.ca/wp-json/tribe/events/v1/" rel="https://theeventscalendar.com"/>
#   <style type="text/css">
#   </style>
#   <style type="text/css">
#    .synved-social-resolution-single {
# display: inline-block;
# }
# .synved-social-resolution-normal {
# display: inline-block;
# }
# .synved-social-resolution-hidef {
# display: none;
# }
#
# @media only screen and (min--moz-device-pixel-ratio: 2),
# only screen and (-o-min-device-pixel-ratio: 2/1),
# only screen and (-webkit-min-device-pixel-ratio: 2),
# only screen and (min-device-pixel-ratio: 2),
# only screen and (min-resolution: 2dppx),
# only screen and (min-resolution: 192dpi) {
# 	.synved-social-resolution-normal {
# 	display: none;
# 	}
# 	.synved-social-resolution-hidef {
# 	display: inline-block;
# 	}
# }
#   </style>
#   <!--[if lt IE 9]>
# 			<script src="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/ie/ie.js"></script>
# 		<![endif]-->
#  </head>
#  <script>
#   (function (w,i,d,g,e,t,s) {w[d] = w[d]||[];t= i.createElement(g);
#     t.async=1;t.src=e;s=i.getElementsByTagName(g)[0];s.parentNode.insertBefore(t, s);
#   })(window, document, '_gscq','script','//widgets.getsitecontrol.com/95546/script.js');
#  </script>
#  <body class="archive post-type-archive post-type-archive-company tribe-no-js tribe-bar-is-disabled">
#   <a class="screen-reader-text skip-link" href="#content">
#    Skip to content
#   </a>
#   <header class="site-header" role="banner">
#    <div class="super-header">
#     <div class="row">
#      <div class="col large-12">
#       <nav aria-label="Secondary" role="navigation">
#        <ul class="navigation secondary-navigation" id="secondary-navigation">
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-18746" id="menu-item-18746">
#          <a href="http://velocity.uwaterloo.ca/newsletter/">
#           Newsletter
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20906" id="menu-item-20906">
#          <a href="https://drive.google.com/drive/folders/0B4uOO03SNdrla2pOZk9qcnNTYzA?usp=sharing">
#           Media Kit
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18747" id="menu-item-18747">
#          <a href="http://velocity.uwaterloo.ca/about-us/contact-velocity/">
#           Contact
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20083" id="menu-item-20083">
#          <a href="https://twitter.com/uwvelocity" target="_blank">
#           <i class="fa fa-twitter">
#           </i>
#           <span class="fontawesome-text">
#            Twitter
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20084" id="menu-item-20084">
#          <a href="https://www.facebook.com/uWaterlooVeloCity?ref=br_rs" target="_blank">
#           <i class="fa fa-facebook">
#           </i>
#           <span class="fontawesome-text">
#            Facebook
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-25110" id="menu-item-25110">
#          <a href="https://www.linkedin.com/company/uwvelocity">
#           <i class="fa fa-linkedin">
#           </i>
#           <span class="fontawesome-text">
#            LinkedIn
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20085" id="menu-item-20085">
#          <a href="https://www.instagram.com/uwvelocity/" target="_blank">
#           <i class="fa fa-instagram">
#           </i>
#           <span class="fontawesome-text">
#            Instagram
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-22526" id="menu-item-22526">
#          <a href="https://www.snapchat.com/add/uwvelocity" target="_blank">
#           <i class="fa fa-snapchat">
#           </i>
#           <span class="fontawesome-text">
#            Snapchat
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-22834" id="menu-item-22834">
#          <a href="https://www.youtube.com/user/uwvelocity/videos" target="_blank">
#           <i class="fa fa-youtube-play">
#           </i>
#           <span class="fontawesome-text">
#            Youtube
#           </span>
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </div>
#    <div class="navigation-bar">
#     <div class="row">
#      <div class="col large-12">
#       <a class="site-logo" href="http://velocity.uwaterloo.ca/" rel="home">
#        <img alt="Velocity" src="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/images/logos/velocity-logo.png"/>
#       </a>
#       <button class="menu-toggle" id="menu-toggle">
#        Toggle navigation visibility
#       </button>
#       <nav aria-label="Primary" role="navigation">
#        <ul class="navigation primary-navigation" id="primary-navigation">
#         <li class="u-hidden-large menu-item menu-item-type-post_type menu-item-object-page menu-item-26485" id="menu-item-26485">
#          <a href="http://velocity.uwaterloo.ca/events/">
#           Events
#          </a>
#         </li>
#         <li class="yellownav menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-18749" id="menu-item-18749">
#          <a href="http://velocity.uwaterloo.ca/about-us/">
#           About Us
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18750" id="menu-item-18750">
#            <a href="http://velocity.uwaterloo.ca/about-us/the-velocity-team/">
#             The Velocity Team
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-19068" id="menu-item-19068">
#            <a href="https://formstack.io/B2E06">
#             Book a Tour
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18754" id="menu-item-18754">
#            <a href="http://velocity.uwaterloo.ca/about-us/contact-velocity/">
#             Contact Velocity
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-18755" id="menu-item-18755">
#          <a href="http://velocity.uwaterloo.ca/programs/">
#           Programs
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18761" id="menu-item-18761">
#            <a href="http://velocity.uwaterloo.ca/workspaces/velocity-garage/">
#             Velocity Garage
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20318" id="menu-item-20318">
#            <a href="http://velocity.uwaterloo.ca/programs/velocity-start/">
#             Velocity Start
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18758" id="menu-item-18758">
#            <a href="http://velocity.uwaterloo.ca/programs/velocity-science/">
#             Velocity Science
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18757" id="menu-item-18757">
#            <a href="http://velocity.uwaterloo.ca/programs/velocity-residence/">
#             Velocity Residence
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18764" id="menu-item-18764">
#            <a href="http://velocity.uwaterloo.ca/funding/velocity-fund/">
#             Velocity Fund
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item menu-item-has-children menu-item-24961" id="menu-item-24961">
#          <a href="http://velocity.uwaterloo.ca/companies">
#           Companies
#          </a>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-25319" id="menu-item-25319">
#            <a href="http://velocity.uwaterloo.ca/category/press/">
#             Newsroom
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18763" id="menu-item-18763">
#            <a href="http://velocity.uwaterloo.ca/funding/investors/">
#             Investors
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-30517" id="menu-item-30517">
#          <a href="http://velocity.uwaterloo.ca/10years/">
#           10 Years
#          </a>
#         </li>
#         <li class="u-hidden-small menu-item menu-item-type-post_type menu-item-object-page menu-item-18765" id="menu-item-18765">
#          <a href="http://velocity.uwaterloo.ca/events/">
#           Events
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="row">
#    <main class="col large-12 main-content" id="content" role="main">
#     <div id="companies-list">
#      <div class="row">
#       <div class="col large-9">
#        <h1>
#         Company Directory
#        </h1>
#        <p>
#         More than 100 past and present companies are part of the Velocity ecosystem. Search for them below or discover them by any number of filters.
#        </p>
#       </div>
#      </div>
#      <h3>
#       Filter
#      </h3>
#      <div class="filter-companies">
#       <div class="row">
#        <div class="col large-3 medium-4">
#         <div>
#          <button class="btn--bare expand-btn expand-btn--expanded js-expand-filters-btn">
#           Sector
#          </button>
#         </div>
#         <div class="filters-container js-filters">
#          <button class="filter-btn js-filter-button" data-category="900.Clean Tech">
#           Clean Tech
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Energy">
#           Energy
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Fintech">
#           Fintech
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Environment">
#           Environment
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Marketplace">
#           Marketplace
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Internet of Things">
#           Internet of Things
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Education">
#           Education
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Entertainment">
#           Entertainment
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Health Tech">
#           Health Tech
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.Consumer">
#           Consumer
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="900.B2B">
#           B2B
#          </button>
#          <br/>
#         </div>
#        </div>
#        <div class="col large-3 medium-4">
#         <div>
#          <button class="btn--bare expand-btn expand-btn--expanded js-expand-filters-btn">
#           Status
#          </button>
#         </div>
#         <div class="filters-container js-filters">
#          <button class="filter-btn js-filter-button" data-category="901.Current">
#           Current
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="901.Alumni">
#           Alumni
#          </button>
#          <br/>
#         </div>
#        </div>
#        <div class="col large-3 medium-4">
#         <div>
#          <button class="btn--bare expand-btn expand-btn--expanded js-expand-filters-btn">
#           Type
#          </button>
#         </div>
#         <div class="filters-container js-filters">
#          <button class="filter-btn js-filter-button" data-category="902.Other">
#           Other
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="902.Science">
#           Science
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="902.Hardware">
#           Hardware
#          </button>
#          <br/>
#          <button class="filter-btn js-filter-button" data-category="902.Software">
#           Software
#          </button>
#          <br/>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="clearfix">
#       <div class="company-search-container">
#        <label class="screen-reader-text" for="company-search">
#         Search Companies by Name
#        </label>
#        <input class="company-search search" id="company-search" placeholder="Search by Name" type="text"/>
#       </div>
#       <div class="company-view-toggle-container">
#        <button class="btn--bare list-btn active-view-btn js-toggle-company-list-view">
#         List View
#        </button>
#        <button class="btn--bare grid-btn js-toggle-company-grid-view">
#         Grid View
#        </button>
#       </div>
#      </div>
#      <div class="row js-list-view-titles" style="display: none;">
#       <div class="col large-3">
#        <h3>
#         Company Name
#        </h3>
#       </div>
#       <div class="col large-9">
#        <h3>
#         Description
#        </h3>
#       </div>
#      </div>
#      <ul class="o-list-bare list js-company-list">
#       <li class="js-company">
#        <article class="post-30615 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-hardware company-type-health-tech company-type-science">
#         <div class="js-list-view">
#          <div class="company-card company-card--list">
#           <div class="row">
#            <div class="col large-3">
#             <h2 class="company-title--list u-no-margin-bottom">
#              <a href="http://www.alineorthopaedics.com" target="blank">
#               A-Line Orthopaedics
#              </a>
#             </h2>
#            </div>
#            <div class="col large-8">
#             <p>
#              A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.
#             </p>
#            </div>
#            <div class="col large-1">
#             <a href="http://velocity.uwaterloo.ca/companies/a-line-orthopaedics/">
#              →
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="js-grid-view" style="display: none;">
#          <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.alineorthopaedics.com" target="blank">
#           <div class="company-card-image">
#            <img alt="A-Line Logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/04/A-Line-Logo-Large-450x320.png" width="450">
#            </img>
#           </div>
#           <div class="company-content">
#            <h2 class="company-title companyTitle">
#             A-Line Orthopaedics
#            </h2>
#            <p>
#             A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.
#            </p>
#            <div class="swp-content-locator">
#            </div>
#            <div class="hidden companyCategory">
#             900.B2B, 901.Current, 902.Hardware, 900.Health Tech, 902.Science
#            </div>
#           </div>
#          </a>
#         </div>
#        </article>
#       </li>
#       <li class="js-company">
#        <article class="post-26972 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current">
#         <div class="js-list-view">
#          <div class="company-card company-card--list">
#           <div class="row">
#            <div class="col large-3">
#             <h2 class="company-title--list u-no-margin-bottom">
#              <a href="http://www.aalo.co" target="blank">
#               Aalo
#              </a>
#             </h2>
#            </div>
#            <div class="col large-8">
#             <p>
#              Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.
#             </p>
#            </div>
#            <div class="col large-1">
#             <a href="http://velocity.uwaterloo.ca/companies/aalo/">
#              →
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="js-grid-view" style="display: none;">
#          <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.aalo.co" target="blank">
#           <div class="company-card-image">
#            <img alt="Aalo for website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/07/Aalo-for-website-450x320.jpg" width="450"/>
#           </div>
#           <div class="company-content">
#            <h2 class="company-title companyTitle">
#             Aalo
#            </h2>
#            <p>
#             Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.
#            </p>
#            <div class="swp-content-locator">
#            </div>
#            <div class="hidden companyCategory">
#             900.B2B, 901.Current
#            </div>
#           </div>
#          </a>
#         </div>
#        </article>
#       </li>
#       <li class="js-company">
#        <article class="post-20226 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-software">
#         <div class="js-list-view">
#          <div class="company-card company-card--list">
#           <div class="row">
#            <div class="col large-3">
#             <h2 class="company-title--list u-no-margin-bottom">
#              <a href="http://acerta.ca" target="blank">
#               Acerta
#              </a>
#             </h2>
#            </div>
#            <div class="col large-8">
#             <p>
#              A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.
#             </p>
#            </div>
#            <div class="col large-1">
#             <a href="http://velocity.uwaterloo.ca/companies/acerta/">
#              →
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="js-grid-view" style="display: none;">
#          <a class="company-card comapny-card--grid js-company-card--grid" href="http://acerta.ca" target="blank">
#           <div class="company-card-image">
#            <img alt="Test" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/01/Test-1-450x320.png" width="450"/>
#           </div>
#           <div class="company-content">
#            <h2 class="company-title companyTitle">
#             Acerta
#            </h2>
#            <p>
#             A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.
#            </p>
#            <div class="swp-content-locator">
#            </div>
#           </div>
#          </a>
#         </div>
#        </article>
#       </li>
#      </ul>
#     </div>
#    </main>
#   </div>
#  </body>
# </html>
# Founders: Greta Cutulenco, Sebastian Fischmeister, Jean-Christophe Petkovich
# <div class="hidden companyCategory">
#  900.B2B, 901.Current, 902.Software
# </div>
# <li class="js-company">
#  <article class="post-19154 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://acornbiolabs.com/" target="blank">
#         Acorn Biolabs
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p class="p1">
#        Cryopreserving people’s healthy young cells for use with future medical technologies.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/acornbiolabs/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://acornbiolabs.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="acorn-new-for-website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/Acorn-NEW-for-Website-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Acorn Biolabs
#      </h2>
#      <p>
#       Cryopreserving people’s healthy young cells for use with future medical technologies.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Steven ten Holder, Laura Vaughan, Patrick Pumputis
# <div class="hidden companyCategory">
#  901.Alumni, 900.Consumer, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-18856 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-hardware company-type-health-tech company-type-internet-of-things">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.getairo.com" target="blank">
#         AIRO Health
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        A wearable nutrition tracker that actively monitors a user’s caloric intake.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/airo/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.getairo.com" target="blank">
#     <div class="company-card-image">
#      <img alt="AIRO" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/AIRO-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       AIRO Health
#      </h2>
#      <p>
#       A wearable nutrition tracker that actively monitors a user’s caloric intake.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Emmanuel DeVries, Naman Kumar
# <div class="hidden companyCategory">
#  901.Alumni, 900.Consumer, 902.Hardware, 900.Health Tech, 900.Internet of Things
# </div>
# <li class="js-company">
#  <article class="post-18869 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-consumer company-type-current company-type-hardware company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.alchemynano.com" target="blank">
#         Alchemy
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <p class="p1">
#        <span class="s1">
#         Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.
#        </span>
#       </p>
#       <h2>
#       </h2>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/alchemy/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.alchemynano.com" target="blank">
#     <div class="company-card-image">
#      <img alt="Alchemy-Velocity-Red" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Alchemy-Velocity-Red-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Alchemy
#      </h2>
#      <p>
#       Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Khanjan Desai, Chong Shen
# <div class="hidden companyCategory">
#  900.B2B, 900.Consumer, 901.Current, 902.Hardware, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-29700 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="https://www.altiusanalyticslabs.com" target="blank">
#         Altius Analytics Labs
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/altius-analytics-labs/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.altiusanalyticslabs.com" target="blank">
#     <div class="company-card-image">
#      <img alt="Altius for Website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/01/Altius-for-Website-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Altius Analytics Labs
#      </h2>
#      <p>
#       Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#      <div class="hidden companyCategory">
#       901.Alumni
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# <li class="js-company">
#  <article class="post-18872 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-consumer company-type-current company-type-hardware company-type-health-tech company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="https://www.aminahealth.com/" target="blank">
#         Amina Health
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <p>
#        Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/amina/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.aminahealth.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Amina Health" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Amina-Health-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Amina Health
#      </h2>
#      <p>
#       Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: James MacLean, Nirushan Udayakumar, Bobby Green
# <div class="hidden companyCategory">
#  900.B2B, 900.Consumer, 901.Current, 902.Hardware, 900.Health Tech, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-18807 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-education company-type-software">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="https://www.applyboard.com/" target="blank">
#         ApplyBoard
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p class="p1">
#        Helps international students apply to universities and colleges in North America through an all-in-one application platform.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/applyboard/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.applyboard.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="applyboard image" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/applyboard-image-450x320.jpeg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       ApplyBoard
#      </h2>
#      <p>
#       Helps international students apply to universities and colleges in North America through an all-in-one application platform.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Martin Basiri, Meti Basiri, Sina Sadeghian
# <div class="hidden companyCategory">
#  901.Alumni, 900.B2B, 900.Consumer, 900.Education, 902.Software
# </div>
# <li class="js-company">
#  <article class="post-22077 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-fintech company-type-software">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://arkparadigm.com/" target="blank">
#         Ark Paradigm
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p class="p1">
#        A regulatory intelligence service to report financial material free of errors and omissions.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/ark-paradigm/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://arkparadigm.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Test" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/05/Test-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Ark Paradigm
#      </h2>
#      <p>
#       A regulatory intelligence service to report financial material free of errors and omissions.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Murray Love, Umar Khan
# <div class="hidden companyCategory">
#  901.Alumni, 900.B2B, 900.Fintech, 902.Software
# </div>
# <li class="js-company">
#  <article class="post-19161 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.arylla.com/" target="blank">
#         Arylla
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <p>
#        Secure nano ink that combats fraud and improves top line revenue.
#       </p>
#       <h2>
#       </h2>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/arylla/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.arylla.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Arylla" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/Arylla-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Arylla
#      </h2>
#      <p>
#       Secure nano ink that combats fraud and improves top line revenue.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Benjamin Rasera, Graham Thomas, Perry Everett
# <div class="hidden companyCategory">
#  900.B2B, 901.Current, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-18886 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-health-tech company-type-software">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.avidbots.com/" target="blank">
#         Avidbots
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        Smart cleaning robots for autonomous commercial floor cleaning.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/avidbots/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.avidbots.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="AVIDBOTS" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/AVIDBOTS-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Avidbots
#      </h2>
#      <p>
#       Smart cleaning robots for autonomous commercial floor cleaning.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Faizan Sheikh, Pablo Molina, Ken Andersen
# <div class="hidden companyCategory">
#  901.Alumni, 900.Consumer, 900.Health Tech, 902.Software
# </div>
# <li class="js-company">
#  <article class="post-21089 company type-company status-publish has-post-thumbnail hentry company-type-consumer company-type-current company-type-health-tech company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.avrolifesci.com/" target="blank">
#         AVRO Life Science
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <p>
#        Medicated stickers to deliver seasonal allergy medication to children.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/avro-life-science/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.avrolifesci.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Logo(black small)" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/03/Logoblack-small-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       AVRO Life Science
#      </h2>
#      <p>
#       Medicated stickers to deliver seasonal allergy medication to children.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Keean Sarani, Tom Chong, Shak Lakhani, Jiwoo Jang
# <div class="hidden companyCategory">
#  900.Consumer, 901.Current, 900.Health Tech, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-24007 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-software">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.babylonvr.ca" target="blank">
#         Babylon VR
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <div class="page" title="Page 7">
#        <div class="section">
#         <div class="layoutArea">
#          <div class="column">
#           <p>
#            <span data-sheets-userformat='{"2":12288,"15":"Calibri","16":12}' data-sheets-value='{"1":2,"2":"A content creation tool for virtual reality."}'>
#             A content creation tool for virtual reality.
#            </span>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/babylon-vr/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.babylonvr.ca" target="blank">
#     <div class="company-card-image">
#      <img alt="babylon_website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/11/babylon_website-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Babylon VR
#      </h2>
#      <p>
#       A content creation tool for virtual reality.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Qasim Arron, Usman Aaron, Jack Liu, Matt Zhong
# <div class="hidden companyCategory">
#  900.B2B, 901.Current, 902.Software
# </div>
# <li class="js-company">
#  <article class="post-18866 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-hardware">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.bartesian.com/" target="blank">
#         Bartesian
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        A modern mixology system that creates premium cocktails on demand.
#       </p>
#       <h2>
#       </h2>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/bartesian/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.bartesian.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="BARTESIAN" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/BARTESIAN-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Bartesian
#      </h2>
#      <p>
#       A modern mixology system that creates premium cocktails on demand.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Bryan Fedorak, Ryan Close
# <div class="hidden companyCategory">
#  901.Alumni, 900.B2B, 900.Consumer, 902.Hardware
# </div>
# <li class="js-company">
# ...
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       VivaSpire
#      </h2>
#      <p>
#       Compact and portable oxygen delivery systems for patients in need of oxygen therapy.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Pablo Enrique, John Grousopoulos, Chris Hajduk, Mostafa Saquib
# <div class="hidden companyCategory">
#  900.Consumer, 901.Current, 902.Hardware, 900.Health Tech, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-18857 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-hardware">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://volterainc.com/" target="blank">
#         Voltera
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        A desktop circuit board printer that helps build hardware faster.
#       </p>
#       <h2>
#       </h2>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/voltera/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://volterainc.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Voltera" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Voltera-450x320.png" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Voltera
#      </h2>
#      <p>
#       A desktop circuit board printer that helps build hardware faster.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Alroy Almeida, James Pickard, Jesus A Zozaya, Katarina Ilic
# <div class="hidden companyCategory">
#  901.Alumni, 900.B2B, 902.Hardware
# </div>
# <li class="js-company">
#  <article class="post-24654 company type-company status-publish has-post-thumbnail hentry company-type-current company-type-other company-type-science">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.willowcup.com/" target="blank">
#         Willow Cup
#        </a>
#       </h2>
#      </div>
#      <div class="col large-8">
#       <p class="p1">
#        <span class="s1">
#         Sustainable plant-based milk that is delicious and nutritious.
#        </span>
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/willow-cup/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.willowcup.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="Willow Cup Logo Velocity Website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Willow-Cup-Logo-Velocity-Website-450x320.jpeg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Willow Cup
#      </h2>
#      <p>
#       Sustainable plant-based milk that is delicious and nutritious.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Sara Bonham, Craig Deebank
# <div class="hidden companyCategory">
#  901.Current, 902.Other, 902.Science
# </div>
# <li class="js-company">
#  <article class="post-26202 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-software">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://velocity.uwaterloo.ca/companies/worldvuze/" target="blank">
#         WorldVuze
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/worldvuze/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://velocity.uwaterloo.ca/companies/worldvuze/" target="blank">
#     <div class="company-card-image">
#      <img alt="WorldVuze logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/05/WorldVuze-logo-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       WorldVuze
#      </h2>
#      <p>
#       WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#      <div class="hidden companyCategory">
#       901.Alumni, 900.Consumer, 902.Software
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# <li class="js-company">
#  <article class="post-18790 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://wriber.com/" target="blank">
#         Wriber
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        A content optimization platform that helps you drive more traffic and customers to your website.
#       </p>
#       <h2>
#       </h2>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/wriber/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://wriber.com/" target="blank">
#     <div class="company-card-image">
#      <img alt="WRIBER" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/WRIBER-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       Wriber
#      </h2>
#      <p>
#       A content optimization platform that helps you drive more traffic and customers to your website.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: John Zupancic
# <div class="hidden companyCategory">
#  901.Alumni
# </div>
# <li class="js-company">
#  <article class="post-19728 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#   <div class="js-list-view">
#    <div class="company-card company-card--list">
#     <div class="row">
#      <div class="col large-3">
#       <h2 class="company-title--list u-no-margin-bottom">
#        <a href="http://www.zpharm.ca" target="blank">
#         zpharm
#        </a>
#       </h2>
#       <p class="company-category">
#        Velocity Alumni
#       </p>
#      </div>
#      <div class="col large-8">
#       <p>
#        Innovative medicines for a variety of disease states.
#       </p>
#      </div>
#      <div class="col large-1">
#       <a href="http://velocity.uwaterloo.ca/companies/zpharm/">
#        →
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="js-grid-view" style="display: none;">
#    <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.zpharm.ca" target="blank">
#     <div class="company-card-image">
#      <img alt="zpharm logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/10/zpharm-logo-450x320.jpg" width="450"/>
#     </div>
#     <div class="company-content">
#      <h2 class="company-title companyTitle">
#       zpharm
#      </h2>
#      <p>
#       Innovative medicines for a variety of disease states.
#      </p>
#      <div class="swp-content-locator">
#      </div>
#     </div>
#    </a>
#   </div>
#  </article>
# </li>
# Founders: Blake Ziegler
# <div class="hidden companyCategory">
#  901.Alumni
# </div>
# <footer class="site-footer" id="footer" role="contentinfo">
#  <div class="row">
#   <div class="col large-12">
#    <p class="footer-address">
#     Velocity | 200 University Avenue West | Waterloo, Ontario, Canada N2L 3G1
#     <br/>
#     <br/>
#     <a href="https://twitter.com/uwvelocity" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/twitter.gif"/>
#     </a>
#     <a href="https://www.facebook.com/uWaterlooVeloCity?ref=br_rs" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/facebook.gif"/>
#     </a>
#     <a href="https://www.linkedin.com/company/uwvelocity" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/02/linkedin.gif"/>
#     </a>
#     <a href="https://instagram.com/uwvelocity" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/11/instagram-black.png"/>
#     </a>
#     <a href="https://www.snapchat.com/add/uwvelocity" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/08/snapchat.png"/>
#     </a>
#     <a href="https://www.youtube.com/user/uwvelocity/videos" style="padding-right: 10px;" target="_blank">
#      <img src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/youtube.gif"/>
#     </a>
#    </p>
#    <a class="waterloo-logo" href="https://uwaterloo.ca" rel="home">
#     <img alt="Velocity" src="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/images/logos/university-of-waterloo-logo.png"/>
#    </a>
#   </div>
#  </div>
# </footer>
# <!-- ngg_resource_manager_marker -->
# <script src="http://velocity.uwaterloo.ca/wp-content/plugins/contact-form-7/includes/js/jquery.form.min.js?ver=3.51.0-2014.06.20" type="text/javascript">
# </script>
# <script type="text/javascript">
#  /* <![CDATA[ */
# var _wpcf7 = {"loaderUrl":"http:\/\/velocity.uwaterloo.ca\/wp-content\/plugins\/contact-form-7\/images\/ajax-loader.gif","recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}},"sending":"Sending ..."};
# /* ]]> */
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=4.5" type="text/javascript">
# </script>
# <script type="text/javascript">
#  /* <![CDATA[ */
# var JQLBSettings = {"fitToScreen":"0","resizeSpeed":"400","displayDownloadLink":"0","navbarOnTop":"0","loopImages":"","resizeCenter":"","marginSize":"","linkTarget":"_self","help":"","prevLinkTitle":"previous image","nextLinkTitle":"next image","prevLinkText":"\u00ab Previous","nextLinkText":"Next \u00bb","closeTitle":"close image gallery","image":"Image ","of":" of ","download":"Download","jqlb_overlay_opacity":"80","jqlb_overlay_color":"#000000","jqlb_overlay_close":"1","jqlb_border_width":"10","jqlb_border_color":"#ffffff","jqlb_border_radius":"0","jqlb_image_info_background_transparency":"100","jqlb_image_info_bg_color":"#ffffff","jqlb_image_info_text_color":"#000000","jqlb_image_info_text_fontsize":"10","jqlb_show_text_for_image":"1","jqlb_next_image_title":"next image","jqlb_previous_image_title":"previous image","jqlb_next_button_image":"http:\/\/velocity.uwaterloo.ca\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/next.gif","jqlb_previous_button_image":"http:\/\/velocity.uwaterloo.ca\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/prev.gif","jqlb_maximum_width":"","jqlb_maximum_height":"","jqlb_show_close_button":"1","jqlb_close_image_title":"close image gallery","jqlb_close_image_max_heght":"22","jqlb_image_for_close_lightbox":"http:\/\/velocity.uwaterloo.ca\/wp-content\/plugins\/wp-lightbox-2\/styles\/images\/closelabel.gif","jqlb_keyboard_navigation":"1","jqlb_popup_size_fix":"0"};
# /* ]]> */
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-content/plugins/wp-lightbox-2/wp-lightbox-2.min.js?ver=1.3.4.1" type="text/javascript">
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-content/plugins/social-warfare/js/script.min.js?ver=2.3.3" type="text/javascript">
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/js/list.min.js?ver=1.1.1" type="text/javascript">
# </script>
# <script type="text/javascript">
#  /* <![CDATA[ */
# var velocitySettings = {"themeURL":"http:\/\/velocity.uwaterloo.ca\/wp-content\/themes\/Velocity-02282017","ajaxURL":"http:\/\/velocity.uwaterloo.ca\/wp-admin\/admin-ajax.php","nonce":"0544863da3"};
# /* ]]> */
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-content/themes/Velocity-02282017/js/scripts.js?ver=1.0" type="text/javascript">
# </script>
# <script src="http://velocity.uwaterloo.ca/wp-includes/js/wp-embed.min.js?ver=4.6.11" type="text/javascript">
# </script>
# <!-- tracker added by Ultimate Google Analytics plugin v1.6.0: http://www.oratransplant.nl/uga -->
# <script type="text/javascript">
#  var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
# document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
#  var pageTracker = _gat._getTracker("UA-3059836-7");
# pageTracker._initData();
# pageTracker._trackPageview();
# </script>
# <script>
#  ( function ( body ) {
# 			'use strict';
# 			body.className = body.className.replace( /\btribe-no-js\b/, 'tribe-js' );
# 		} )( document.body );
# </script>
# <script type="text/javascript">
#  /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done"}};/* ]]> */
# </script>
# <script type="text/javascript">
#  swpPinIt={"enabled":false};var swpClickTracking = false; var swp_nonce = "0562132f22";
# </script>

# %%
companies_html = soup.findAll('li',class_="js-company") #finding tags with <li> with classes <js-company>

# %%
companies_html #displaying sorted html
# Out:
# [<li class="js-company">
#  <article class="post-30615 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-hardware company-type-health-tech company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.alineorthopaedics.com" target="blank">A-Line Orthopaedics</a></h2> </div>
#  <div class="col large-8">
#  <p>A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/a-line-orthopaedics/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.alineorthopaedics.com" target="blank">
#  <div class="company-card-image">
#  <img alt="A-Line Logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/04/A-Line-Logo-Large-450x320.png" width="450"> </img></div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">A-Line Orthopaedics</h2> <p>A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">900.B2B, 901.Current, 902.Hardware, 900.Health Tech, 902.Science</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-26972 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.aalo.co" target="blank">Aalo</a></h2> </div>
#  <div class="col large-8">
#  <p>Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/aalo/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.aalo.co" target="blank">
#  <div class="company-card-image">
#  <img alt="Aalo for website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/07/Aalo-for-website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Aalo</h2> <p>Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">900.B2B, 901.Current</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-20226 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://acerta.ca" target="blank">Acerta</a></h2> </div>
#  <div class="col large-8">
#  <p>A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/acerta/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://acerta.ca" target="blank">
#  <div class="company-card-image">
#  <img alt="Test" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/01/Test-1-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Acerta</h2> <p>A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-19154 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://acornbiolabs.com/" target="blank">Acorn Biolabs</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p class="p1">Cryopreserving people’s healthy young cells for use with future medical technologies.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/acornbiolabs/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://acornbiolabs.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="acorn-new-for-website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/Acorn-NEW-for-Website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Acorn Biolabs</h2> <p>Cryopreserving people’s healthy young cells for use with future medical technologies.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18856 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-hardware company-type-health-tech company-type-internet-of-things">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.getairo.com" target="blank">AIRO Health</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A wearable nutrition tracker that actively monitors a user’s caloric intake.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/airo/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.getairo.com" target="blank">
#  <div class="company-card-image">
#  <img alt="AIRO" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/AIRO-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">AIRO Health</h2> <p>A wearable nutrition tracker that actively monitors a user’s caloric intake.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18869 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-consumer company-type-current company-type-hardware company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.alchemynano.com" target="blank">Alchemy</a></h2> </div>
#  <div class="col large-8">
#  <p class="p1"><span class="s1">Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.</span></p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/alchemy/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.alchemynano.com" target="blank">
#  <div class="company-card-image">
#  <img alt="Alchemy-Velocity-Red" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Alchemy-Velocity-Red-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Alchemy</h2> <p>Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-29700 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.altiusanalyticslabs.com" target="blank">Altius Analytics Labs</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/altius-analytics-labs/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.altiusanalyticslabs.com" target="blank">
#  <div class="company-card-image">
#  <img alt="Altius for Website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/01/Altius-for-Website-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Altius Analytics Labs</h2> <p>Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">901.Alumni</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-18872 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-consumer company-type-current company-type-hardware company-type-health-tech company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.aminahealth.com/" target="blank">Amina Health</a></h2> </div>
#  <div class="col large-8">
#  <p>Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/amina/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.aminahealth.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Amina Health" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Amina-Health-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Amina Health</h2> <p>Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18807 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-education company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.applyboard.com/" target="blank">ApplyBoard</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p class="p1">Helps international students apply to universities and colleges in North America through an all-in-one application platform.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/applyboard/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.applyboard.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="applyboard image" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/applyboard-image-450x320.jpeg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">ApplyBoard</h2> <p>Helps international students apply to universities and colleges in North America through an all-in-one application platform.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-22077 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-fintech company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://arkparadigm.com/" target="blank">Ark Paradigm</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p class="p1">A regulatory intelligence service to report financial material free of errors and omissions.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/ark-paradigm/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://arkparadigm.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Test" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/05/Test-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Ark Paradigm</h2> <p>A regulatory intelligence service to report financial material free of errors and omissions.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-19161 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.arylla.com/" target="blank">Arylla</a></h2> </div>
#  <div class="col large-8">
#  <p>Secure nano ink that combats fraud and improves top line revenue.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/arylla/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.arylla.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Arylla" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/07/Arylla-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Arylla</h2> <p>Secure nano ink that combats fraud and improves top line revenue.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18886 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-health-tech company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.avidbots.com/" target="blank">Avidbots</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Smart cleaning robots for autonomous commercial floor cleaning.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/avidbots/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.avidbots.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="AVIDBOTS" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/AVIDBOTS-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Avidbots</h2> <p>Smart cleaning robots for autonomous commercial floor cleaning.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-21089 company type-company status-publish has-post-thumbnail hentry company-type-consumer company-type-current company-type-health-tech company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.avrolifesci.com/" target="blank">AVRO Life Science</a></h2> </div>
#  <div class="col large-8">
#  <p>Medicated stickers to deliver seasonal allergy medication to children.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/avro-life-science/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.avrolifesci.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Logo(black small)" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/03/Logoblack-small-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">AVRO Life Science</h2> <p>Medicated stickers to deliver seasonal allergy medication to children.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24007 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.babylonvr.ca" target="blank">Babylon VR</a></h2> </div>
#  <div class="col large-8">
#  <div class="page" title="Page 7">
#  <div class="section">
#  <div class="layoutArea">
#  <div class="column">
#  <p><span data-sheets-userformat='{"2":12288,"15":"Calibri","16":12}' data-sheets-value='{"1":2,"2":"A content creation tool for virtual reality."}'>A content creation tool for virtual reality.</span></p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/babylon-vr/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.babylonvr.ca" target="blank">
#  <div class="company-card-image">
#  <img alt="babylon_website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/11/babylon_website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Babylon VR</h2> <p>A content creation tool for virtual reality.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18866 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-hardware">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.bartesian.com/" target="blank">Bartesian</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A modern mixology system that creates premium cocktails on demand.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bartesian/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.bartesian.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="BARTESIAN" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/BARTESIAN-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Bartesian</h2> <p>A modern mixology system that creates premium cocktails on demand.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-30056 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://bibulabs.com/" target="blank">Bibu Labs</a></h2> </div>
#  <div class="col large-8">
#  <p>Dynamic defence mechanism against cyberattacks.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bibu-labs/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://bibulabs.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Bibu_Labs_Logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/02/Bibu_Labs_Logo-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Bibu Labs</h2> <p>Dynamic defence mechanism against cyberattacks.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">900.B2B, 901.Current, 902.Software</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-18820 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://blitzen.com/" target="blank">Blitzen</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Helps SMB marketers convert website visitors into data-rich leads, and capture key customer insights.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/blitzen/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://blitzen.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="BLITZEN" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/BLITZEN-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Blitzen</h2> <p>Helps SMB marketers convert website visitors into data-rich leads, and capture key customer insights.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24434 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-education company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://velocity.uwaterloo.ca/companies/bookneto/" target="blank">Bookneto</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>(Acquired by Canadian Innovation Centre, 2013). Bookneto is a Q&amp;A tool built on top of Waterloo’s online learning platform (LEARN).</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bookneto/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://velocity.uwaterloo.ca/companies/bookneto/" target="blank">
#  <div class="company-card-image">
#  <img alt="Bookneto" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Bookneto-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Bookneto</h2> <p>(Acquired by Canadian Innovation Centre, 2013). Bookneto is a Q&amp;A tool built on top of Waterloo’s online learning platform (LEARN).</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-20449 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-clean-tech company-type-current company-type-energy company-type-environment company-type-hardware">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.borealiswind.com" target="blank">Borealis Wind</a></h2> </div>
#  <div class="col large-8">
#  <p class="p1"><span class="s1">A wind turbine de-icing system that is low maintenance and easy to install. </span></p>
#  <h2 class="p1"></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/boreas-wind-turbine-solutions/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.borealiswind.com" target="blank">
#  <div class="company-card-image">
#  <img alt="NewBorealis" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/01/NewBorealis-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Borealis Wind</h2> <p>A wind turbine de-icing system that is low maintenance and easy to install.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-26794 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-marketplace company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.bridesmade.ca" target="blank">BridesMade</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p class="p1"><span data-sheets-userformat='{"2":14851,"3":{"1":0},"4":{"1":2,"2":16777215},"12":0,"14":{"1":2,"2":4473924},"15":"wf_segoe-ui_normal, \"Segoe UI\", \"Segoe WP\", Tahoma, Arial, sans-serif","16":11}' data-sheets-value='{"1":2,"2":"BridesMade is an online portal that allows bridesmaids to rent size-adjustable bridesmaid dresses that are shipped right to their doorsteps."}'>BridesMade is an online portal that allows bridesmaids to rent size-adjustable bridesmaid dresses that are shipped right to their doorsteps.</span></p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bridesmade/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.bridesmade.ca" target="blank">
#  <div class="company-card-image">
#  <img alt="BridesMade VW" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/07/BridesMade-VW--450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">BridesMade</h2> <p>BridesMade is an online portal that allows bridesmaids to rent size-adjustable bridesmaid dresses that are shipped right to their doorsteps.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">901.Alumni, 900.Consumer, 900.Marketplace, 902.Software</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-22687 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://gobridgit.com/" target="blank">Bridgit</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Software for the construction industry to streamline communications and improves productivity.</p>
#  <h2 class="p1"></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bridgit/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://gobridgit.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Velocity-Bridgit" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/08/Velocity-Bridgit-450x320.jpeg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Bridgit</h2> <p>Software for the construction industry to streamline communications and improves productivity.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18814 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-hardware">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://en.wikipedia.org/wiki/BufferBox" target="blank">BufferBox</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>(Acquired by Google, 2012). Automated self-serve kiosks for consumers to retrieve shipped parcels at their convenience.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/bufferbox/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://en.wikipedia.org/wiki/BufferBox" target="blank">
#  <div class="company-card-image">
#  <img alt="BUFFERBOX" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/BUFFERBOX-450x320.gif" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">BufferBox</h2> <p>(Acquired by Google, 2012). Automated self-serve kiosks for consumers to retrieve shipped parcels at their convenience.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24341 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-education company-type-entertainment company-type-hardware company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.cardinote.com/" target="blank">Cardinote</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Maker of Tabophone, a guitar pick that writes music for you automatically.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/cardinote/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.cardinote.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="cardinote_website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Cardinote_Website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Cardinote</h2> <p>Maker of Tabophone, a guitar pick that writes music for you automatically.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18825 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-education company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.chalk.com/" target="blank">Chalk.com</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A platform for teachers with a suite of products for curriculum management, administrator insights, and collaboration.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/chalk-com/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.chalk.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="CHALKCOM" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/CHALKCOM-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Chalk.com</h2> <p>A platform for teachers with a suite of products for curriculum management, administrator insights, and collaboration.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24300 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.charityrepublic.com/" target="blank">Charity Republic</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Volunteer management software that provides effortless volunteer scheduling and tracking.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/charity-republic/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.charityrepublic.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="charity_republic_logo_website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Charity_Republic_Logo_Website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Charity Republic</h2> <p>Volunteer management software that provides effortless volunteer scheduling and tracking.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-30203 company type-company status-publish has-post-thumbnail hentry">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://charitycan.ca" target="blank">CharityCAN</a></h2> </div>
#  <div class="col large-8">
#  <p>Software as a service to help charities quickly find, qualify and make connections with important donors.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/charitycan/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://charitycan.ca" target="blank">
#  <div class="company-card-image">
#  <img alt="CharityCAN" class="attachment-thumbnail size-thumbnail wp-post-image" height="135" src="http://velocity.uwaterloo.ca/wp-content/uploads/2018/03/CharityCAN-450x135.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">CharityCAN</h2> <p>Software as a service to help charities quickly find, qualify and make connections with important donors.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory"></div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-18810 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://chefhero.com/" target="blank">ChefHero</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Helps you order everything for your kitchen in one convenient location.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/chefhero/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://chefhero.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="chef-hero-for-website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Chef-Hero-for-Website-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">ChefHero</h2> <p>Helps you order everything for your kitchen in one convenient location.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-23271 company type-company status-publish has-post-thumbnail hentry company-type-consumer company-type-current company-type-entertainment company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://justchillabit.com/" target="blank">Chillabit</a></h2> </div>
#  <div class="col large-8">
#  <p class="p1"><span class="s1">A social platform where university students meet new people, socialize, and share hilarious stories.</span></p>
#  <h2 class="p1"></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/chillabit/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://justchillabit.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="chillabit" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/09/Chillabit-450x320.jpeg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Chillabit</h2> <p>A social platform where university students meet new people, socialize, and share hilarious stories.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18796 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-consumer company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://codeconnect.io/" target="blank">Code Connect</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>(Acquired by Microsoft, 2016). Code Connect for Visual Studio displays code as the computer will execute it, making complex software projects easier to understand.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/code-connect/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://codeconnect.io/" target="blank">
#  <div class="company-card-image">
#  <img alt="CODECONNECT" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/CODECONNECT-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Code Connect</h2> <p>(Acquired by Microsoft, 2016). Code Connect for Visual Studio displays code as the computer will execute it, making complex software projects easier to understand.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18831 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-education company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://couple.me/" target="blank">Couple</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>(Acquired by Life360, 2016). A relationship app that connects partners around the world.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/couple/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://couple.me/" target="blank">
#  <div class="company-card-image">
#  <img alt="COUPLE" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/COUPLE-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Couple</h2> <p>(Acquired by Life360, 2016). A relationship app that connects partners around the world.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18850 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-consumer company-type-current company-type-hardware company-type-health-tech">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://curiato.com/" target="blank">Curiato</a></h2> </div>
#  <div class="col large-8">
#  <p class="p1">Provides institutions with smart sensor systems to remotely monitor and manage patients at risk of developing pressure related injuries.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/curiato/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://curiato.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="For Website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/For-Website-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Curiato</h2> <p>Provides institutions with smart sensor systems to remotely monitor and manage patients at risk of developing pressure related injuries.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-21802 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-environment company-type-hardware">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://deminerobotics.com" target="blank">Demine Robotics</a></h2> </div>
#  <div class="col large-8">
#  <p>A specialized robot that excavates and neutralizes landmines with limited human interaction.</p>
#  <p> </p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/demine-robotics/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://deminerobotics.com" target="blank">
#  <div class="company-card-image">
#  <img alt="Demine-Robotics" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/05/Demine-Robotics-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Demine Robotics</h2> <p>A specialized robot that excavates and neutralizes landmines with limited human interaction.  </p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18782 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://velocity.uwaterloo.ca/companies/draftingspace/" target="blank">DraftingSPACE</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>(Acquired by BuildDirect, 2015). An automated floor plan generation tool for use in architecture, interior design, and home staging.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/draftingspace/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://velocity.uwaterloo.ca/companies/draftingspace/" target="blank">
#  <div class="company-card-image">
# ...
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/ubiq-2/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.goubiq.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Test" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/07/Test-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Ubiq</h2> <p>Simplifying the AV setup of conference rooms by making it wireless.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18873 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-hardware company-type-internet-of-things">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://uhwk.com/" target="blank">UHWK</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A durable helmet-mounted HD video camera for athletes.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/uhwk/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://uhwk.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="u-hwk.com[2]" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/u-hwk.com2_-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">UHWK</h2> <p>A durable helmet-mounted HD video camera for athletes.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-22398 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-environment company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://twitter.com/upgraininc?lang=en" target="blank">UpGrain</a></h2> </div>
#  <div class="col large-8">
#  <p>Maximizing productivity of seeds through exposure to electromagnetic fields.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/upgrain/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://twitter.com/upgraininc?lang=en" target="blank">
#  <div class="company-card-image">
#  <img alt="UpGrain" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/07/UpGrain-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">UpGrain</h2> <p>Maximizing productivity of seeds through exposure to electromagnetic fields.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24645 company type-company status-publish has-post-thumbnail hentry company-type-b2b company-type-current company-type-hardware company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="https://www.venamed.ca/" target="blank">Vena Medical</a></h2> </div>
#  <div class="col large-8">
#  <p>Vena Medical is creating a forward viewing imaging microcatheter that allows physicians to see inside patient blood vessels.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/jm-medical/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="https://www.venamed.ca/" target="blank">
#  <div class="company-card-image">
#  <img alt="Vena Medical Website Logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Vena-Medical-Website-Logo-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Vena Medical</h2> <p>Vena Medical is creating a forward viewing imaging microcatheter that allows physicians to see inside patient blood vessels.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18867 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.vertical.ai" target="blank">Vertical</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Custom augmented reality experiences for any device.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/vertical/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.vertical.ai" target="blank">
#  <div class="company-card-image">
#  <img alt="vertical" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/vertical-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Vertical</h2> <p>Custom augmented reality experiences for any device.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18813 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://vidyard.com/" target="blank">Vidyard</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>An online video platform for marketing and sales that provides video hosting, management, and analytics.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/vidyard/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://vidyard.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="vidyard" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/vidyard-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Vidyard</h2> <p>An online video platform for marketing and sales that provides video hosting, management, and analytics.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-22198 company type-company status-publish has-post-thumbnail hentry company-type-consumer company-type-current company-type-hardware company-type-health-tech company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://vivaspire.ca/" target="blank">VivaSpire</a></h2> </div>
#  <div class="col large-8">
#  <p>Compact and portable oxygen delivery systems for patients in need of oxygen therapy.</p>
#  <h2 class="p1"></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/vivaspire/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://vivaspire.ca/" target="blank">
#  <div class="company-card-image">
#  <img alt="VivaSpire" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2016/06/VivaSpire-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">VivaSpire</h2> <p>Compact and portable oxygen delivery systems for patients in need of oxygen therapy.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-18857 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-b2b company-type-hardware">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://volterainc.com/" target="blank">Voltera</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A desktop circuit board printer that helps build hardware faster.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/voltera/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://volterainc.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Voltera" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/Voltera-450x320.png" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Voltera</h2> <p>A desktop circuit board printer that helps build hardware faster.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-24654 company type-company status-publish has-post-thumbnail hentry company-type-current company-type-other company-type-science">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.willowcup.com/" target="blank">Willow Cup</a></h2> </div>
#  <div class="col large-8">
#  <p class="p1"><span class="s1">Sustainable plant-based milk that is delicious and nutritious.</span></p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/willow-cup/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.willowcup.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="Willow Cup Logo Velocity Website" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/01/Willow-Cup-Logo-Velocity-Website-450x320.jpeg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Willow Cup</h2> <p>Sustainable plant-based milk that is delicious and nutritious.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-26202 company type-company status-publish has-post-thumbnail hentry company-type-alumni company-type-consumer company-type-software">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://velocity.uwaterloo.ca/companies/worldvuze/" target="blank">WorldVuze</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/worldvuze/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://velocity.uwaterloo.ca/companies/worldvuze/" target="blank">
#  <div class="company-card-image">
#  <img alt="WorldVuze logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2017/05/WorldVuze-logo-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">WorldVuze</h2> <p>WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.</p>
#  <div class="swp-content-locator"></div> <div class="hidden companyCategory">901.Alumni, 900.Consumer, 902.Software</div>
#  </div>
#  </a>
#  </div>
#  </article>
#  </li>, <li class="js-company">
#  <article class="post-18790 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://wriber.com/" target="blank">Wriber</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>A content optimization platform that helps you drive more traffic and customers to your website.</p>
#  <h2></h2>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/wriber/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://wriber.com/" target="blank">
#  <div class="company-card-image">
#  <img alt="WRIBER" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/06/WRIBER-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">Wriber</h2> <p>A content optimization platform that helps you drive more traffic and customers to your website.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>, <li class="js-company">
#  <article class="post-19728 company type-company status-publish has-post-thumbnail hentry company-type-alumni">
#  <div class="js-list-view">
#  <div class="company-card company-card--list">
#  <div class="row">
#  <div class="col large-3">
#  <h2 class="company-title--list u-no-margin-bottom"><a href="http://www.zpharm.ca" target="blank">zpharm</a></h2> <p class="company-category">Velocity Alumni</p> </div>
#  <div class="col large-8">
#  <p>Innovative medicines for a variety of disease states.</p>
#  </div>
#  <div class="col large-1">
#  <a href="http://velocity.uwaterloo.ca/companies/zpharm/">→</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="js-grid-view" style="display: none;">
#  <a class="company-card comapny-card--grid js-company-card--grid" href="http://www.zpharm.ca" target="blank">
#  <div class="company-card-image">
#  <img alt="zpharm logo" class="attachment-thumbnail size-thumbnail wp-post-image" height="320" src="http://velocity.uwaterloo.ca/wp-content/uploads/2015/10/zpharm-logo-450x320.jpg" width="450"/> </div>
#  <div class="company-content">
#  <h2 class="company-title companyTitle">zpharm</h2> <p>Innovative medicines for a variety of disease states.</p>
#  <div class="swp-content-locator"></div> </div></a></div></article></li>]

# %%
data = [] #defining empty list to add data about companies
#Parser
for i in range(0,147,1):
    company_info = companies_html[i] #indexing through html
    title_companies = company_info.find(class_="company-title companyTitle").get_text() #extracting title by specifying class and extracting it
    desc_companies = company_info.find("p",class_="").get_text() #extracting description of the companies
    enter_data = [title_companies,desc_companies] #entering data in the list
    data.append(enter_data)
    print ("Title of the Company: ", title_companies)
    print ("Description: ", desc_companies)
    
#This loop enters data into the list for us to export to csv
# Out:
# Title of the Company:  A-Line Orthopaedics
# Description:  A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.
# Title of the Company:  Aalo
# Description:  Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.
# Title of the Company:  Acerta
# Description:  A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.
# Title of the Company:  Acorn Biolabs
# Description:  Cryopreserving people’s healthy young cells for use with future medical technologies.
# Title of the Company:  AIRO Health
# Description:  A wearable nutrition tracker that actively monitors a user’s caloric intake.
# Title of the Company:  Alchemy
# Description:  Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.
# Title of the Company:  Altius Analytics Labs
# Description:  Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.
# Title of the Company:  Amina Health
# Description:  Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.
# Title of the Company:  ApplyBoard
# Description:  Helps international students apply to universities and colleges in North America through an all-in-one application platform.
# Title of the Company:  Ark Paradigm
# Description:  A regulatory intelligence service to report financial material free of errors and omissions.
# Title of the Company:  Arylla
# Description:  Secure nano ink that combats fraud and improves top line revenue.
# Title of the Company:  Avidbots
# Description:  Smart cleaning robots for autonomous commercial floor cleaning.
# Title of the Company:  AVRO Life Science
# Description:  Medicated stickers to deliver seasonal allergy medication to children.
# Title of the Company:  Babylon VR
# Description:  A content creation tool for virtual reality.
# Title of the Company:  Bartesian
# Description:  A modern mixology system that creates premium cocktails on demand.
# Title of the Company:  Bibu Labs
# Description:  Dynamic defence mechanism against cyberattacks.
# Title of the Company:  Blitzen
# Description:  Helps SMB marketers convert website visitors into data-rich leads, and capture key customer insights.
# Title of the Company:  Bookneto
# Description:  (Acquired by Canadian Innovation Centre, 2013). Bookneto is a Q&A tool built on top of Waterloo’s online learning platform (LEARN).
# Title of the Company:  Borealis Wind
# Description:  A wind turbine de-icing system that is low maintenance and easy to install.
# Title of the Company:  BridesMade
# Description:  BridesMade is an online portal that allows bridesmaids to rent size-adjustable bridesmaid dresses that are shipped right to their doorsteps.
# Title of the Company:  Bridgit
# Description:  Software for the construction industry to streamline communications and improves productivity.
# Title of the Company:  BufferBox
# Description:  (Acquired by Google, 2012). Automated self-serve kiosks for consumers to retrieve shipped parcels at their convenience.
# Title of the Company:  Cardinote
# Description:  Maker of Tabophone, a guitar pick that writes music for you automatically.
# Title of the Company:  Chalk.com
# Description:  A platform for teachers with a suite of products for curriculum management, administrator insights, and collaboration.
# Title of the Company:  Charity Republic
# Description:  Volunteer management software that provides effortless volunteer scheduling and tracking.
# Title of the Company:  CharityCAN
# Description:  Software as a service to help charities quickly find, qualify and make connections with important donors.
# Title of the Company:  ChefHero
# Description:  Helps you order everything for your kitchen in one convenient location.
# Title of the Company:  Chillabit
# Description:  A social platform where university students meet new people, socialize, and share hilarious stories.
# Title of the Company:  Code Connect
# Description:  (Acquired by Microsoft, 2016). Code Connect for Visual Studio displays code as the computer will execute it, making complex software projects easier to understand.
# Title of the Company:  Couple
# Description:  (Acquired by Life360, 2016). A relationship app that connects partners around the world.
# Title of the Company:  Curiato
# Description:  Provides institutions with smart sensor systems to remotely monitor and manage patients at risk of developing pressure related injuries.
# Title of the Company:  Demine Robotics
# Description:  A specialized robot that excavates and neutralizes landmines with limited human interaction.
# Title of the Company:  DraftingSPACE
# Description:  (Acquired by BuildDirect, 2015). An automated floor plan generation tool for use in architecture, interior design, and home staging.
# Title of the Company:  DropLab
# Description:  Automating lab work using the power of digital microfluidics.
# Title of the Company:  Durata
# Description:  Durata offers a platform that uses cryptocurrencies to help content creators crowdfund.
# Title of the Company:  Elucid Labs
# Description:  An AI-powered hand-held device capable of real-time detection of skin conditions, disease, and cancer.
# Title of the Company:  EMAGIN
# Description:  An intelligence platform that enables water utilities to proactively manage their infrastructure in real-time.
# Title of the Company:  Embark
# Description:  Self-driving vehicles that can save lives, reduce emissions, and free up billions of hours.
# Title of the Company:  Encircle
# Description:  A platform for insurance carriers to improve productivity and transparency across the entire insurance ecosystem.
# Title of the Company:  EnPowered
# Description:  Group buying for energy to help consumers control energy usage and costs.
# Title of the Company:  Envoi
# Description:  Envoi offers retailers an infrastructure for same day delivery in order to meet consumer demand that is not currently fulfilled by traditional courier services.
# Title of the Company:  Eve Tab
# Description:  A nightclub app that allows users to pre-pay bar tabs, skip the line and enter for free.
# Title of the Company:  Expertise Finder
# Description:  A search engine to connect journalists with subject matter experts.
# Title of the Company:  ExVivo Labs
# Description:  Non-invasive allergy testing solutions for physicians, making the experience safe, simple and certain.
# Title of the Company:  Fiix
# Description:  On-demand service for automotive repairs.
# Title of the Company:  Fora
# Description:  (Acquired by Andela, 2014). Provides digital educational content for organizations in Africa using course content developed by world leading experts.
# Title of the Company:  Furevery
# Description:  A community platform that connects dog lovers with professional dog services.
# Title of the Company:  Gamelynx
# Description:  Team-based competitive eSport games for the mobile generation.
# Title of the Company:  Georgette Packaging
# Description:  Custom branded packaging for small businesses.
# Title of the Company:  Greenlight Essentials
# Description:  Software that helps entertainment professionals better understand film industry data.
# Title of the Company:  Grobo
# Description:  A hydroponic grow box to easily grow high-quality food and medicine right at home, all year long.
# Title of the Company:  Ground
# Description:  Ground is the first AI-powered verified news platform.
# Title of the Company:  H2nanO
# Description:  Harnessing solar energy to treat contaminated water quickly, effectively and at low cost.
# Title of the Company:  Halion Displays
# Description:  Low-power outdoor visible display technology to enable the next generation of devices.
# Title of the Company:  HealthIM
# Description:  Provides police with an intelligence driven system to prevent crisis and reduce risk when supporting persons with mental illness in the community.
# Title of the Company:  HearthStats
# Description:  (Acquired by GAMURS, 2016). Statistical feedback to help improve gamers’ performance.
# Title of the Company:  Hedgehog
# Description:  Redesigning the traditional disposable umbrella into a durable and long lasting product.
# Title of the Company:  HelpWear
# Description:  A 24/7 wearable heart monitoring system that detects when the user suffers a heart attack and contacts emergency services.
# Title of the Company:  HITCH
# Description:  HITCH makes hardware and software that intelligently delivers educational videos to private schools in emerging markets.
# Title of the Company:  Hive
# Description:  Helping brands build, engage, and monetize their online audience.
# Title of the Company:  ICSPI
# Description:  The smallest, most simple, and affordable Atomic Force Microscope on the market.
# Title of the Company:  Indigo Fair
# Description:  A wholesale marketplace for independent retail stores.
# Title of the Company:  Innovative Protein Technologies
# Description:  A food-safe crop protection solution for farmers to protect against devastating frosts and ensure crop yields.
# Title of the Company:  Jingu Apps
# Description:  (Acquired by Rebellion Media, 2012). Social apps that make any mobile chat experience more fun.
# Title of the Company:  Kaizena
# Description:  A platform that allows educators to give high-quality feedback, and identify student abilities beyond test scores.
# Title of the Company:  Kik
# Description:  An instant messaging app with over 300 million registered users that lets users connect with friends, and chat-based services.
# Title of the Company:  Kira Talent
# Description:  A platform that allows higher education admissions teams to add interactive videos and written components into admissions applications.
# Title of the Company:  Kitematic
# Description:  (Acquired by Docker, 2015). Runs containers through a simple, yet powerful graphical user interface.
# Title of the Company:  Labforge
# Description:  A network of low energy sensors that use AI to track objects and their movements for perimeter security.
# Title of the Company:  LabsCubed
# Description:  Enabling companies to create new and innovative materials through enhanced testing methods.
# Title of the Company:  Lace
# Description:  Makes it easy to find, compare, and purchase innovative solutions for cities, ranging from administration to transit.
# Title of the Company:  Lightbot
# Description:  Apps that teach kids to code through games.
# Title of the Company:  Linkett
# Description:  Provides live audience data for digital out of home advertising.
# Title of the Company:  Load Army
# Description:  A mobile app that makes it easy for contractors to order dump truck services.
# Title of the Company:  Loop Lab
# Description:  Smart Air Vents that manage temperature on a room by room basis to make your home more comfortable and efficient.
# Title of the Company:  Lumotune
# Description:  Transparent digital displays that look just like glass.
# Title of the Company:  MAJiK Systems
# Description:  Real-time monitoring and analytics that help manufacturers optimize production.
# Title of the Company:  Maluuba
# Description:  (Acquired by Microsoft, 2017). Teaching machines to think, reason and communicate.
# Title of the Company:  Mappedin
# Description:  Dynamic wayfinding for the indoors.
# Title of the Company:  Marlena Books
# Description:  Therapeutic recreation products for individuals with Alzheimer’s or dementia.
# Title of the Company:  Medella Health
# Description:  Medella Health develops novel sensors using machine learning to monitor health biomarkers for medical devices, ranging from smart contact lenses to point-of-care solutions.
# Title of the Company:  Medly Labs
# Description:  A music making app to create songs and share them with people around the world.
# Title of the Company:  MetricWire
# Description:  A mobile platform that helps organizations harness insights, analytics, and deeper audience connections in real-time.
# Title of the Company:  Mirage VR
# Description:  Bringing imagination into reality with a full-body tracking virtual reality experience.
# Title of the Company:  Moocow Unicycles
# Description:  Building durable and lightweight unicycles to optimize performance.
# Title of the Company:  NanoCnet
# Description:  Nanomaterials to enable the creation of flexible, transparent electrodes.
# Title of the Company:  NanoPhyll
# Description:  Smart coatings that are engineered to respond to the local environment.
# Title of the Company:  NanoQuan Inc.
# Description:  Manufactures advanced, high-performance nano composite materials.
# Title of the Company:  NERv
# Description:  An implantable biochip platform to detect post-operative complications.
# Title of the Company:  Nicoya Lifesciences
# Description:  Personal surface plasmon resonance (SPR) instruments designed for the individual researcher at the comfort of their own bench.
# Title of the Company:  Oneset
# Description:  A community app that shares workout ideas through 15 second videos.
# Title of the Company:  OpenPhone
# Description:  OpenPhone adds a second phone number to your existing mobile device along with powerful features to help your small business communicate better.
# Title of the Company:  OSIMple
# Description:  A mobile-first tool to assist bridge inspectors with their on-site inspections.
# Title of the Company:  Ourotech
# Description:  Personalized cancer treatments through measuring drug resistance ex vivo.
# Title of the Company:  Palette
# Description:  Palette is a modular hardware device that provides creators with personalized control of any software.
# Title of the Company:  PASS Kit
# Description:  A first aid kit for mental health to decrease stress in individuals, and stigma in communities.
# Title of the Company:  PaveAI
# Description:  Google Analytics Simplified. PaveAI customizes analytics to your needs and emails you actionable reports from your data.
# Title of the Company:  Pebble
# Description:  (Acquired by Fitbit, 2016). Smartwatches people love.
# Title of the Company:  Pegasus Aeronautics
# Description:  High endurance aerial platforms to extend drone flight times.
# Title of the Company:  Penta Medical
# Description:  A wearable therapeutic system to speed the recovery of injuries and chronic conditions.
# Title of the Company:  PiinPoint
# Description:  A site selection platform that helps business owners discover, compare, and validate locations for expansion.
# Title of the Company:  Pinpress
# Description:  Shape changing technology that reduces manufacturer downtime, consumption, and labor costs.
# Title of the Company:  Pitstop
# Description:  A cloud-based diagnostic platform for automotive vehicles.
# Title of the Company:  Playticipate
# Description:  Helping parents find local kids activities.
# Title of the Company:  Plex.ai
# Description:  An insurance broker that uses artificial intelligence to re-engineer insurance and risk management.
# Title of the Company:  Pout
# Description:  (Acquired by Everalbum, 2016). A community for fashion, beauty, and inspiration.
# Title of the Company:  ProNavigator
# Description:  A B2B company with an AI-powered assistant built for insurance. From getting quotes to asking questions, insurance is as easy as chatting!
# Title of the Company:  Prospect
# Description:  Allows sales teams to accurately target B2B leads.
# Title of the Company:  PumpUp
# Description:  A health and fitness app that provides personal coaching, workouts and a supportive community.
# Title of the Company:  Qidni Labs
# Description:  Artificial kidneys for patients with kidney failure.
# Title of the Company:  Quantwave Technologies
# Description:  Provides faster, cheaper, and simpler pathogen detection for drinking water and food suppliers.
# Title of the Company:  Rebel Hippo
# Description:  Indie game studio.
# Title of the Company:  Reebee
# Description:  An app for shoppers to browse flyers, create lists and search for products.
# Title of the Company:  Relay
# Description:  A messaging platform that helps businesses communicate with customers and conduct transactions inside popular chat apps like Messenger, SMS, and Kik.
# Title of the Company:  Salient Energy
# Description:  Cheaper, safer, and longer-lasting batteries for the grid.
# Title of the Company:  Serenity Bioworks
# Description:  Medicine formulas that improve the safety and long-term effectiveness of anti-inflammatory medication.
# Title of the Company:  Sesame
# Description:  A platform for teachers that provides a living, visual record of student competencies.
# Title of the Company:  ShiftRide
# Description:  ShiftRide is an on-demand mobility platform, allowing people to get access to other people’s cars nearby.
# Title of the Company:  Singspiel
# Description:  An app that helps you learn to play piano with the songs you love.
# Title of the Company:  Sitata
# Description:  Keeps you safe when you travel through real-time health & safety information and by connecting you to trusted support when you need help.
# Title of the Company:  Site2Site
# Description:  A mobile application to automate constructions job sites.
# Title of the Company:  SiteVue
# Description:  A software platform that allows construction managers to capture, organize, and share moments on site with their entire project team.
# Title of the Company:  Smarter Alloys
# Description:  Makes shape memory materials smarter smarter, lighter, and more reliable.
# Title of the Company:  Sortable
# Description:  Automated ad operations, built by publishers for publishers to make ads suck less.
# Title of the Company:  Sparkgig
# Description:  An online marketplace for local musical performers to connect with event opportunities.
# Title of the Company:  Suncayr
# Description:  A smart wearable patch that changes colour to indicate when sunscreen has worn off, helping sunscreen users safely enjoy the sun.
# Title of the Company:  Tabnex
# Description:  An artificial intelligence platform that provides integrated intelligence on candidates to decrease the costs of hiring, and improve the quality of talent pipeline.
# Title of the Company:  TallyFi
# Description:  A simple handheld people-counting solution that provides a live online dashboard with insightful analytics.
# Title of the Company:  Terrene
# Description:  Terrene provides next level business insights by allowing anyone to quickly setup and deploy deep learning neural networks.
# Title of the Company:  Thalmic Labs
# Description:  Wearable technologies that integrate gesture control and human-computer interaction.
# Title of the Company:  TicketFi
# Description:  A simple yet powerful ticketing platform.
# Title of the Company:  Tinker
# Description:  Technology that builds trading algorithms for a variety of digital assets like Bitcoin.
# Title of the Company:  TrendRadius
# Description:  (Acquired by Intelex, 2015). Customer feedback analytics for product managers.
# Title of the Company:  TritonWear
# Description:  High performance wearable tech for competitive swimmers.
# Title of the Company:  Tugolo
# Description:  Tugolo enables authentic, unique, and culture-rich travel experiences.
# Title of the Company:  Ubiq
# Description:  Simplifying the AV setup of conference rooms by making it wireless.
# Title of the Company:  UHWK
# Description:  A durable helmet-mounted HD video camera for athletes.
# Title of the Company:  UpGrain
# Description:  Maximizing productivity of seeds through exposure to electromagnetic fields.
# Title of the Company:  Vena Medical
# Description:  Vena Medical is creating a forward viewing imaging microcatheter that allows physicians to see inside patient blood vessels.
# Title of the Company:  Vertical
# Description:  Custom augmented reality experiences for any device.
# Title of the Company:  Vidyard
# Description:  An online video platform for marketing and sales that provides video hosting, management, and analytics.
# Title of the Company:  VivaSpire
# Description:  Compact and portable oxygen delivery systems for patients in need of oxygen therapy.
# Title of the Company:  Voltera
# Description:  A desktop circuit board printer that helps build hardware faster.
# Title of the Company:  Willow Cup
# Description:  Sustainable plant-based milk that is delicious and nutritious.
# Title of the Company:  WorldVuze
# Description:  WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.
# Title of the Company:  Wriber
# Description:  A content optimization platform that helps you drive more traffic and customers to your website.
# Title of the Company:  zpharm
# Description:  Innovative medicines for a variety of disease states.

# %%
data #printing the list
# Out:
# [['A-Line Orthopaedics',
#   'A-Line is developing safer, faster and less invasive implants for minimally-invasive spine surgery that improve patient outcomes and surgeon confidence.'],
#  ['Aalo',
#   'Creative furniture assembly system that brings effortless, inch-by-inch personalization to the objects that make up your dynamic living space.'],
#  ['Acerta',
#   'A machine learning platform that detects anomalies in vehicle data to decrease manufacturing costs, and improve quality.'],
#  ['Acorn Biolabs',
#   'Cryopreserving people’s healthy young cells for use with future medical technologies.'],
#  ['AIRO Health',
#   'A wearable nutrition tracker that actively monitors a user’s caloric intake.'],
#  ['Alchemy',
#   'Protective film for windshields to prevent stone chips, block solar infrared heat, and prevent overnight frost.'],
#  ['Altius Analytics Labs',
#   'Developing seamless motion analysis technology for workplace musculoskeletal injury prevention.'],
#  ['Amina Health',
#   'Allows users to track their nutrition levels with a single drop of blood and buy customized supplements based on what their bodies’ actually need.'],
#  ['ApplyBoard',
#   'Helps international students apply to universities and colleges in North America through an all-in-one application platform.'],
#  ['Ark Paradigm',
#   'A regulatory intelligence service to report financial material free of errors and omissions.'],
#  ['Arylla',
#   'Secure nano ink that combats fraud and improves top line revenue.'],
#  ['Avidbots',
#   'Smart cleaning robots for autonomous commercial floor cleaning.'],
#  ['AVRO Life Science',
#   'Medicated stickers to deliver seasonal allergy medication to children.'],
#  ['Babylon VR', 'A content creation tool for virtual reality.'],
#  ['Bartesian',
#   'A modern mixology system that creates premium cocktails on demand.'],
#  ['Bibu Labs', 'Dynamic defence mechanism against cyberattacks.'],
#  ['Blitzen',
#   'Helps SMB marketers convert website visitors into data-rich leads, and capture key customer insights.'],
#  ['Bookneto',
#   '(Acquired by Canadian Innovation Centre, 2013). Bookneto is a Q&A tool built on top of Waterloo’s online learning platform (LEARN).'],
#  ['Borealis Wind',
#   'A wind turbine de-icing system that is low maintenance and easy to install.'],
#  ['BridesMade',
#   'BridesMade is an online portal that allows bridesmaids to rent size-adjustable bridesmaid dresses that are shipped right to their doorsteps.'],
#  ['Bridgit',
#   'Software for the construction industry to streamline communications and improves productivity.'],
#  ['BufferBox',
#   '(Acquired by Google, 2012). Automated self-serve kiosks for consumers to retrieve shipped parcels at their convenience.'],
#  ['Cardinote',
#   'Maker of Tabophone, a guitar pick that writes music for you automatically.'],
#  ['Chalk.com',
#   'A platform for teachers with a suite of products for curriculum management, administrator insights, and collaboration.'],
#  ['Charity Republic',
#   'Volunteer management software that provides effortless volunteer scheduling and tracking.'],
#  ['CharityCAN',
#   'Software as a service to help charities quickly find, qualify and make connections with important donors.'],
#  ['ChefHero',
#   'Helps you order everything for your kitchen in one convenient location.'],
#  ['Chillabit',
#   'A social platform where university students meet new people, socialize, and share hilarious stories.'],
#  ['Code Connect',
#   '(Acquired by Microsoft, 2016). Code Connect for Visual Studio displays code as the computer will execute it, making complex software projects easier to understand.'],
#  ['Couple',
#   '(Acquired by Life360, 2016). A relationship app that connects partners around the world.'],
#  ['Curiato',
#   'Provides institutions with smart sensor systems to remotely monitor and manage patients at risk of developing pressure related injuries.'],
#  ['Demine Robotics',
#   'A specialized robot that excavates and neutralizes landmines\xa0with limited human interaction.'],
#  ['DraftingSPACE',
#   '(Acquired by BuildDirect, 2015). An automated floor plan generation tool for use in architecture, interior design, and home staging.'],
#  ['DropLab', 'Automating lab work using the power of digital microfluidics.'],
#  ['Durata',
#   'Durata offers a platform that uses cryptocurrencies to help content creators crowdfund.'],
#  ['Elucid Labs',
#   'An AI-powered\xa0hand-held device capable of real-time detection of skin conditions, disease, and cancer.'],
#  ['EMAGIN',
#   'An intelligence platform that enables water utilities to proactively manage their infrastructure in real-time.'],
#  ['Embark',
#   'Self-driving vehicles that can save lives, reduce emissions, and free up billions of hours.'],
#  ['Encircle',
#   'A platform for insurance carriers to improve productivity and transparency across the entire insurance ecosystem.'],
#  ['EnPowered',
#   'Group buying for energy to help consumers control energy usage and costs.'],
#  ['Envoi',
#   'Envoi offers retailers an infrastructure for same day delivery in order to meet consumer demand that is not currently fulfilled by traditional courier services.'],
#  ['Eve Tab',
#   'A nightclub app that allows users to pre-pay bar tabs, skip the line and enter for free.'],
#  ['Expertise Finder',
#   'A search engine to connect journalists with subject matter experts. '],
#  ['ExVivo Labs',
#   'Non-invasive allergy testing solutions for physicians, making the experience safe, simple and certain.'],
#  ['Fiix', 'On-demand service for automotive repairs.'],
#  ['Fora',
#   '(Acquired by Andela, 2014). Provides digital educational content for organizations in Africa using course content developed by world leading experts.'],
#  ['Furevery',
#   'A community platform that connects dog lovers with professional dog services. '],
#  ['Gamelynx',
#   'Team-based competitive eSport games for the mobile generation.'],
#  ['Georgette Packaging', 'Custom branded packaging for small businesses.'],
#  ['Greenlight Essentials',
#   'Software that helps entertainment professionals better understand film industry data.'],
#  ['Grobo',
#   'A hydroponic grow box to easily grow high-quality food and medicine right at home, all year long.'],
#  ['Ground', 'Ground is the first AI-powered verified news platform.'],
#  ['H2nanO',
#   'Harnessing solar energy to treat contaminated water quickly, effectively and at low cost.'],
#  ['Halion Displays',
#   'Low-power outdoor visible display technology to enable the next generation of devices.'],
#  ['HealthIM',
#   'Provides police with an intelligence driven system to prevent crisis and reduce risk when supporting persons with mental illness in the community.'],
#  ['HearthStats',
#   '(Acquired by GAMURS, 2016). Statistical feedback to help improve gamers’ performance.'],
#  ['Hedgehog',
#   'Redesigning the traditional disposable umbrella into a durable and long lasting product.'],
#  ['HelpWear',
#   'A 24/7 wearable heart monitoring system that detects when the user suffers a heart attack and contacts emergency services.'],
#  ['HITCH',
#   'HITCH makes hardware and software that intelligently delivers educational videos to private schools in emerging markets.'],
#  ['Hive', 'Helping brands build, engage, and monetize their online audience.'],
#  ['ICSPI',
#   'The smallest, most simple, and affordable Atomic Force Microscope on the market.'],
#  ['Indigo Fair', 'A wholesale marketplace for independent retail stores. '],
#  ['Innovative Protein Technologies',
#   'A food-safe crop protection solution for farmers to protect against devastating frosts and ensure crop yields.'],
#  ['Jingu Apps',
#   '(Acquired by Rebellion Media, 2012). Social apps that make any mobile chat experience more fun.'],
#  ['Kaizena',
#   'A platform that allows educators to give high-quality feedback, and identify student abilities beyond test scores.'],
#  ['Kik',
#   'An instant messaging app with over 300 million registered users that lets users connect with friends, and chat-based services.'],
#  ['Kira Talent',
#   'A platform that allows higher education admissions teams to add interactive videos and written components into admissions applications.'],
#  ['Kitematic',
#   '(Acquired by Docker, 2015). Runs containers through a simple, yet powerful graphical user interface.'],
#  ['Labforge',
#   'A network of low energy sensors that use AI to\xa0track objects and their movements for perimeter security.'],
#  ['LabsCubed',
#   'Enabling companies to create new and innovative materials through enhanced testing methods.'],
#  ['Lace',
#   'Makes it easy to find, compare, and purchase innovative solutions for cities, ranging from administration to transit.'],
#  ['Lightbot', 'Apps that teach kids to code through games.'],
#  ['Linkett',
#   'Provides live audience data for digital out of home advertising.'],
#  ['Load Army',
#   'A mobile app that makes it easy for contractors to order dump truck services.'],
#  ['Loop Lab',
#   'Smart Air Vents that manage temperature on a room by room basis to make your home more comfortable and efficient.'],
#  ['Lumotune', 'Transparent digital displays that look just like glass.'],
#  ['MAJiK Systems',
#   'Real-time monitoring and analytics that help manufacturers optimize production.'],
#  ['Maluuba',
#   '(Acquired by Microsoft, 2017). Teaching machines to think, reason and communicate.'],
#  ['Mappedin', 'Dynamic wayfinding for the indoors.'],
#  ['Marlena Books',
#   'Therapeutic recreation products for individuals with Alzheimer’s or dementia.'],
#  ['Medella Health',
#   'Medella Health develops novel sensors using machine learning to monitor health biomarkers for medical devices, ranging from smart contact lenses to point-of-care solutions.\xa0'],
#  ['Medly Labs',
#   'A music making app to create songs and share them with people around the world.'],
#  ['MetricWire',
#   'A mobile platform that helps organizations harness insights, analytics, and deeper audience connections in real-time.'],
#  ['Mirage VR',
#   'Bringing imagination into reality with a full-body tracking virtual reality experience.'],
#  ['Moocow Unicycles',
#   'Building durable and lightweight unicycles\xa0to optimize performance.'],
#  ['NanoCnet',
#   'Nanomaterials to enable the creation of flexible, transparent electrodes.'],
#  ['NanoPhyll',
#   'Smart coatings that are engineered to respond to the local environment.'],
#  ['NanoQuan Inc.',
#   'Manufactures advanced, high-performance nano composite materials.'],
#  ['NERv',
#   'An implantable biochip platform to detect post-operative complications.'],
#  ['Nicoya Lifesciences',
#   'Personal surface plasmon resonance (SPR) instruments designed for the individual researcher at the comfort of their own bench.'],
#  ['Oneset',
#   'A community app that shares workout ideas through 15 second videos.'],
#  ['OpenPhone',
#   'OpenPhone adds a second phone number to your existing mobile device along with powerful features to help your small business communicate better.'],
#  ['OSIMple',
#   'A mobile-first tool to assist bridge inspectors with their on-site inspections.'],
#  ['Ourotech',
#   'Personalized cancer treatments through measuring drug resistance ex vivo.'],
#  ['Palette',
#   'Palette is a modular hardware device that provides creators with personalized control of any software.'],
#  ['PASS Kit',
#   'A first aid kit for mental health to decrease stress in individuals, and stigma in communities.'],
#  ['PaveAI',
#   'Google Analytics Simplified. PaveAI customizes analytics to your needs and emails you actionable reports from your data.'],
#  ['Pebble', '(Acquired by Fitbit, 2016). Smartwatches people love.'],
#  ['Pegasus Aeronautics',
#   'High endurance aerial platforms to extend drone flight times.'],
#  ['Penta Medical',
#   'A wearable therapeutic system to speed the recovery of injuries and chronic conditions.'],
#  ['PiinPoint',
#   'A site selection platform that helps business owners\xa0discover, compare, and validate locations for expansion.'],
#  ['Pinpress',
#   'Shape changing technology that reduces manufacturer downtime, consumption, and labor costs.'],
#  ['Pitstop', 'A cloud-based diagnostic platform for automotive vehicles.'],
#  ['Playticipate', 'Helping parents find local kids activities.'],
#  ['Plex.ai',
#   'An insurance broker that uses artificial intelligence to re-engineer insurance and risk management.'],
#  ['Pout',
#   '(Acquired by Everalbum, 2016). A community for fashion, beauty, and inspiration.'],
#  ['ProNavigator',
#   'A B2B company with an AI-powered assistant built for insurance. From getting quotes to asking questions, insurance is as easy as chatting!'],
#  ['Prospect', 'Allows sales teams to accurately target B2B leads.'],
#  ['PumpUp',
#   'A health and fitness app that provides\xa0personal coaching, workouts and a supportive community.'],
#  ['Qidni Labs', 'Artificial kidneys for patients with kidney failure.'],
#  ['Quantwave Technologies',
#   'Provides faster, cheaper, and simpler pathogen detection for drinking water and food suppliers.'],
#  ['Rebel Hippo', 'Indie game studio.'],
#  ['Reebee',
#   'An app for shoppers to browse flyers, create lists and search for products.'],
#  ['Relay',
#   'A messaging platform that helps businesses communicate with customers and conduct transactions inside popular chat apps like Messenger, SMS, and Kik.'],
#  ['Salient Energy',
#   'Cheaper, safer, and longer-lasting batteries for the grid.'],
#  ['Serenity Bioworks',
#   'Medicine formulas that improve the safety and long-term effectiveness of anti-inflammatory medication.'],
#  ['Sesame',
#   'A platform for teachers that provides a living, visual record of student competencies.'],
#  ['ShiftRide',
#   'ShiftRide is an on-demand mobility platform, allowing people to get access to other people’s cars nearby.'],
#  ['Singspiel',
#   'An app that helps you learn to play piano with the songs you love.'],
#  ['Sitata',
#   'Keeps you safe when you travel through real-time health & safety information and by connecting you to trusted support when you need help.'],
#  ['Site2Site', 'A mobile application to automate constructions job sites.'],
#  ['SiteVue',
#   'A software platform that allows construction managers to capture, organize, and share moments on site with their entire project team.'],
#  ['Smarter Alloys',
#   'Makes shape memory materials smarter smarter, lighter, and more reliable.'],
#  ['Sortable',
#   'Automated ad operations, built by publishers for publishers to make ads suck less.'],
#  ['Sparkgig',
#   'An online marketplace for local musical performers to connect with event opportunities.'],
#  ['Suncayr',
#   'A smart wearable patch that changes colour to indicate when sunscreen has worn off, helping sunscreen users safely enjoy the sun.'],
#  ['Tabnex',
#   'An artificial intelligence platform that provides integrated intelligence on candidates to decrease the costs of hiring, and improve the quality of talent pipeline.'],
#  ['TallyFi',
#   'A simple handheld people-counting solution that provides a live online dashboard with insightful analytics.'],
#  ['Terrene',
#   'Terrene provides next level business insights by allowing anyone to quickly setup and deploy deep learning neural networks.'],
#  ['Thalmic Labs',
#   'Wearable technologies that integrate gesture control and human-computer interaction.'],
#  ['TicketFi', 'A simple yet powerful ticketing platform.'],
#  ['Tinker',
#   'Technology that builds trading algorithms for a variety of digital assets like Bitcoin.'],
#  ['TrendRadius',
#   '(Acquired by Intelex, 2015). Customer feedback analytics for product managers.'],
#  ['TritonWear', 'High performance wearable tech for competitive swimmers.'],
#  ['Tugolo',
#   'Tugolo\xa0enables authentic, unique, and culture-rich travel experiences.'],
#  ['Ubiq',
#   'Simplifying the AV setup of conference rooms by making it wireless.'],
#  ['UHWK', 'A durable helmet-mounted HD video camera for athletes.'],
#  ['UpGrain',
#   'Maximizing productivity of seeds through exposure to electromagnetic fields.'],
#  ['Vena Medical',
#   'Vena Medical is creating a forward viewing imaging microcatheter that allows physicians to see inside patient blood vessels.'],
#  ['Vertical', 'Custom augmented reality experiences for\xa0any device.'],
#  ['Vidyard',
#   'An online video platform\xa0for marketing and sales that provides video hosting, management, and analytics.'],
#  ['VivaSpire',
#   'Compact and portable oxygen delivery systems for patients in need of oxygen therapy.'],
#  ['Voltera',
#   'A desktop circuit board printer that helps build hardware faster.'],
#  ['Willow Cup',
#   'Sustainable plant-based milk that is delicious and nutritious.'],
#  ['WorldVuze',
#   'WorldVuze is a safe global discussion platform where K-12 students can share and explore perspectives with other students around the world.'],
#  ['Wriber',
#   'A content optimization platform that helps you drive more traffic and customers to your website.'],
#  ['zpharm', 'Innovative medicines for a variety of disease states.']]

# %%
with open('velocity.csv','w') as file:
    writer = csv.writer(file)
    writer.writerows(data)
    
#writes the data into a .csv file
